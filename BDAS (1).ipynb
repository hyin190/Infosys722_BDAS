# %%
import findspark 
findspark.init("/home/ubuntu/spark-2.1.1-bin-hadoop2.7")
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("hyin190_BDAS").getOrCreate()

# %%
df = spark.read.csv('./PRSA_Data_Aotizhongxin_20130301-20170228.csv',header='True',inferSchema =True)

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-46-648e98153481> in <module>()
# ----> 1 from pyspark.ml.stat import Correlation
#
# ImportError: No module named 'pyspark.ml.stat'

# %%
df.show()
# Out:
# +----+----+---+---+---+
# |PM25|PM20|SO2|NO2| O3|
# +----+----+---+---+---+
# |   1|2013|  3|  1|  0|
# |   2|2013|  3|  1|  1|
# |   3|2013|  3|  1|  2|
# |   4|2013|  3|  1|  3|
# |   5|2013|  3|  1|  4|
# |   6|2013|  3|  1|  5|
# |   7|2013|  3|  1|  6|
# |   8|2013|  3|  1|  7|
# |   9|2013|  3|  1|  8|
# |  10|2013|  3|  1|  9|
# |  11|2013|  3|  1| 10|
# |  12|2013|  3|  1| 11|
# |  13|2013|  3|  1| 12|
# |  14|2013|  3|  1| 13|
# |  15|2013|  3|  1| 14|
# |  16|2013|  3|  1| 15|
# |  17|2013|  3|  1| 16|
# |  18|2013|  3|  1| 17|
# |  19|2013|  3|  1| 18|
# |  20|2013|  3|  1| 19|
# +----+----+---+---+---+
# only showing top 20 rows

# %%
df.columns
# Out:
# ['No',
#  'year',
#  'month',
#  'day',
#  'hour',
#  'PM25',
#  'PM10',
#  'SO2',
#  'NO2',
#  'CO',
#  'O3',
#  'TEMP',
#  'PRES',
#  'DEWP',
#  'RAIN',
#  'wd',
#  'WSPM',
#  'station']

# %%
df.count()
# Out:
# 35064

# %%
df.printSchema()
# Out:
# root
#  |-- PM25: integer (nullable = true)
#  |-- PM20: integer (nullable = true)
#  |-- SO2: string (nullable = true)
#  |-- NO2: string (nullable = true)
#  |-- O3: string (nullable = true)

# %%
import pandas as pd
aotizhongxin= pd.read_csv('./PRSA_Data_Aotizhongxin_20130301-20170228.csv')

# %%
print(aotizhongxin.dtypes)
# Out:
# No           int64
# year         int64
# month        int64
# day          int64
# hour         int64
# PM25       float64
# PM10       float64
# SO2        float64
# NO2        float64
# CO         float64
# O3         float64
# TEMP       float64
# PRES       float64
# DEWP       float64
# RAIN       float64
# wd          object
# WSPM       float64
# station     object
# dtype: object

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
aotizhongxin["PM25"].plot.hist()
plt.show()
aotizhongxin["PM10"].plot.hist()
plt.show()
aotizhongxin["SO2"].plot.hist()
plt.show()
aotizhongxin["NO2"].plot.hist()
plt.show()
aotizhongxin["CO"].plot.hist()
plt.show()
aotizhongxin["O3"].plot.hist()
plt.show()

# %%
corr = aotizhongxin.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col0 {
#             background-color:  #b40426;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col1 {
#             background-color:  #bd1f2d;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col2 {
#             background-color:  #86a9fc;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col3 {
#             background-color:  #455cce;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col4 {
#             background-color:  #485fd1;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col5 {
#             background-color:  #7a9df8;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col6 {
#             background-color:  #5572df;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col7 {
#             background-color:  #516ddb;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col8 {
#             background-color:  #96b7ff;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col9 {
#             background-color:  #a3c2fe;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col10 {
#             background-color:  #b6cefa;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col11 {
#             background-color:  #bed2f6;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col12 {
#             background-color:  #efcebd;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col13 {
#             background-color:  #b3cdfb;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col14 {
#             background-color:  #4c66d6;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row0_col15 {
#             background-color:  #bed2f6;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col0 {
#             background-color:  #bd1f2d;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col1 {
#             background-color:  #b40426;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col2 {
#             background-color:  #455cce;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col3 {
#             background-color:  #3e51c5;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col4 {
#             background-color:  #485fd1;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col5 {
#             background-color:  #799cf8;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col6 {
#             background-color:  #5673e0;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col7 {
#             background-color:  #6180e9;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col8 {
#             background-color:  #8fb1fe;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col9 {
#             background-color:  #9fbfff;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col10 {
#             background-color:  #bbd1f8;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col11 {
#             background-color:  #b9d0f9;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col12 {
#             background-color:  #efcfbf;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col13 {
#             background-color:  #a7c5fe;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col14 {
#             background-color:  #4b64d5;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row1_col15 {
#             background-color:  #c6d6f1;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col0 {
#             background-color:  #86a9fc;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col1 {
#             background-color:  #3b4cc0;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col2 {
#             background-color:  #b40426;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col3 {
#             background-color:  #4358cb;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col4 {
#             background-color:  #485fd1;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col5 {
#             background-color:  #88abfd;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col6 {
#             background-color:  #6384eb;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col7 {
#             background-color:  #516ddb;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col8 {
#             background-color:  #c4d5f3;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col9 {
#             background-color:  #a1c0ff;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col10 {
#             background-color:  #93b5fe;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col11 {
#             background-color:  #e3d9d3;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col12 {
#             background-color:  #cfdaea;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col13 {
#             background-color:  #f1cdba;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col14 {
#             background-color:  #4f69d9;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row2_col15 {
#             background-color:  #82a6fb;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col0 {
#             background-color:  #80a3fa;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col1 {
#             background-color:  #6e90f2;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col2 {
#             background-color:  #7ea1fa;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col3 {
#             background-color:  #b40426;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col4 {
#             background-color:  #485fd1;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col5 {
#             background-color:  #84a7fc;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col6 {
#             background-color:  #7597f6;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col7 {
#             background-color:  #8badfd;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col8 {
#             background-color:  #aec9fc;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col9 {
#             background-color:  #8db0fe;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col10 {
#             background-color:  #abc8fd;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col11 {
#             background-color:  #d2dbe8;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col12 {
#             background-color:  #d4dbe6;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col13 {
#             background-color:  #cfdaea;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col14 {
#             background-color:  #4a63d3;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row3_col15 {
#             background-color:  #a5c3fe;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row4_col0 {
#             background-color:  #7b9ff9;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row4_col1 {
#             background-color:  #7093f3;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row4_col2 {
#             background-color:  #7b9ff9;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row4_col3 {
#             background-color:  #4055c8;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row4_col4 {
#             background-color:  #b40426;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row4_col5 {
#             background-color:  #7ea1fa;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row4_col6 {
#             background-color:  #7295f4;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row4_col7 {
#             background-color:  #92b4fe;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row4_col8 {
#             background-color:  #9fbfff;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row4_col9 {
#             background-color:  #86a9fc;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row4_col10 {
#             background-color:  #e5d8d1;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5row4_col11 {
#             background-color:  #e4d9d2;
#         }    #T_02ed9408_c86d_11eb_89f4_12a75e0b66a5r

# %%
dm2=df.na.drop(how="any",subset="PM10")

# %%
print(aotizhongxin.isnull().any())
# Out:
# No         False
# year       False
# month      False
# day        False
# hour       False
# PM25        True
# PM10        True
# SO2         True
# NO2         True
# CO          True
# O3          True
# TEMP        True
# PRES        True
# DEWP        True
# RAIN        True
# wd          True
# WSPM        True
# station    False
# dtype: bool

# %%
aotizhongxin[["PM25","PM10","SO2","NO2","CO","O3"]].boxplot()
plt.show()

# %%
df.select(df["year"],df["month"],df["day"],df["hour"],df["PM25"],df["PM10"],df["SO2"],df["NO2"],df["CO"],df["O3"],df["station"]).show()
# Out:
# +----+-----+---+----+----+----+---+---+---+---+------------+
# |year|month|day|hour|PM25|PM10|SO2|NO2| CO| O3|     station|
# +----+-----+---+----+----+----+---+---+---+---+------------+
# |2013|    3|  1|   0|   4|   4|  4|  7|300| 77|Aotizhongxin|
# |2013|    3|  1|   1|   8|   8|  4|  7|300| 77|Aotizhongxin|
# |2013|    3|  1|   2|   7|   7|  5| 10|300| 73|Aotizhongxin|
# |2013|    3|  1|   3|   6|   6| 11| 11|300| 72|Aotizhongxin|
# |2013|    3|  1|   4|   3|   3| 12| 12|300| 72|Aotizhongxin|
# |2013|    3|  1|   5|   5|   5| 18| 18|400| 66|Aotizhongxin|
# |2013|    3|  1|   6|   3|   3| 18| 32|500| 50|Aotizhongxin|
# |2013|    3|  1|   7|   3|   6| 19| 41|500| 43|Aotizhongxin|
# |2013|    3|  1|   8|   3|   6| 16| 43|500| 45|Aotizhongxin|
# |2013|    3|  1|   9|   3|   8| 12| 28|400| 59|Aotizhongxin|
# |2013|    3|  1|  10|   3|   6|  9| 12|400| 72|Aotizhongxin|
# |2013|    3|  1|  11|   3|   6|  9| 14|400| 71|Aotizhongxin|
# |2013|    3|  1|  12|   3|   6|  7| 13|300| 74|Aotizhongxin|
# |2013|    3|  1|  13|   3|   6|  7| 12|400| 76|Aotizhongxin|
# |2013|    3|  1|  14|   6|   9|  7| 11|400| 77|Aotizhongxin|
# |2013|    3|  1|  15|   8|  15|  7| 14|400| 76|Aotizhongxin|
# |2013|    3|  1|  16|   9|  19|  9| 13|400| 76|Aotizhongxin|
# |2013|    3|  1|  17|  10|  23| 11| 15|400| 74|Aotizhongxin|
# |2013|    3|  1|  18|  11|  20|  8| 20|500| 70|Aotizhongxin|
# |2013|    3|  1|  19|   8|  14| 12| 30|500| 60|Aotizhongxin|
# +----+-----+---+----+----+----+---+---+---+---+------------+
# only showing top 20 rows

# %%
print(pd.isnull(aotizhongxin).sum())
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM25        925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
pd_df = aotizhongxin[["year","month","day","hour","PM25","PM10","SO2","NO2","CO","O3","station"]]
pd_df = pd_df.dropna(axis=0,how='any')
print(pd.isna(pd_df).sum())
print(pd_df.shape)
# Out:
# year       0
# month      0
# day        0
# hour       0
# PM25       0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# station    0
# dtype: int64
# (31896, 11)

# %%
from pyspark.sql import functions as sf
df = df.withColumn('date', 

                    sf.concat(sf.col('year'),sf.lit('-'), sf.col('month'),sf.lit('-'), sf.col('day'),sf.lit(' '), sf.col('hour'),sf.lit(':00:00')))

df.show()
# Out:
# +---+----+-----+---+----+----+----+---+---+---+---+----+------+-----+----+---+----+------------+-----------------+
# | No|year|month|day|hour|PM25|PM10|SO2|NO2| CO| O3|TEMP|  PRES| DEWP|RAIN| wd|WSPM|     station|             date|
# | 19|2013|    3|  1|  18|  11|  20|  8| 20|500| 70| 3.1|1027.4|-18.4|   0|NNE| 2.1|Aotizhongxin|2013-3-1 18:00:00|
# | 20|2013|    3|  1|  19|   8|  14| 12| 30|500| 60| 2.3|1028.3|-18.4|   0|  N| 2.8|Aotizhongxin|2013-3-1 19:00:00|
# +---+----+-----+---+----+----+----+---+---+---+---+----+------+-----+----+---+----+------------+-----------------+
# only showing top 20 rows

# %%
for x in pd_df[["PM25","PM10","SO2","NO2","CO","O3"]]:
    q75, q25 = np.percentile(pd_df.loc[:, x], [75, 25])
    intr_qr = q75 - q25
    max = q75 + (1.5 * intr_qr)
    min = q25 - (1.5 * intr_qr)

    pd_df.loc[pd_df[x] < min, x] = intr_qr
    pd_df.loc[pd_df[x] > max, x] = intr_qr
pd_df[["PM25","PM10","SO2","NO2","CO","O3"]].boxplot()
plt.show()

# %%
pd_df['Time']= pd_df['year'].map(str)+'-'+pd_df['month'].map(str)+'-'+ pd_df['day'].map(str)+' '+ pd_df['hour'].map(str)+':00:00'
pd_df = pd_df[["PM25","PM10","SO2","NO2","CO","O3","station","Time"]]

# %%
for x in pd_df[["NO2"]]:
    pd_df.loc[pd_df[x] <= 40, "NO2_group"] = "Good"
    pd_df.loc[pd_df[x] >= 41, "NO2_group"] = "Moderate"
    pd_df.loc[pd_df[x] >= 81, "NO2_group"] = "Unhealthy for Sensitive"
    pd_df.loc[pd_df[x] >= 181, "NO2_group"] = "Unhealthy"
    pd_df.loc[pd_df[x] >= 281, "NO2_group"] = "Very unhealthy"
    pd_df.loc[pd_df[x] >= 566, "NO2_group"] = "Hazardous"
for x in pd_df[["SO2"]]:
    pd_df.loc[pd_df[x] <= 50, "SO2_group"] = "Good"
    pd_df.loc[pd_df[x] >= 51, "SO2_group"] = "Moderate"
    pd_df.loc[pd_df[x] >= 150, "SO2_group"] = "Unhealthy for Sensitive"
    pd_df.loc[pd_df[x] >= 476, "SO2_group"] = "Unhealthy"
    pd_df.loc[pd_df[x] >= 801, "SO2_group"] = "Very unhealthy"
    pd_df.loc[pd_df[x] >= 1601, "SO2_group"] = "Hazardous"
for x in pd_df[["PM10"]]:
    pd_df.loc[pd_df[x] <= 50, "PM10_group"] = "Good"
    pd_df.loc[pd_df[x] >= 51, "PM10_group"] = "Moderate"
    pd_df.loc[pd_df[x] >= 151, "PM10_group"] = "Unhealthy for Sensitive"
    pd_df.loc[pd_df[x] >= 251, "PM10_group"] = "Unhealthy"
    pd_df.loc[pd_df[x] >= 351, "PM10_group"] = "Very unhealthy"
    pd_df.loc[pd_df[x] >= 421, "PM10_group"] = "Hazardous"
for x in pd_df[["CO"]]:
    pd_df.loc[pd_df[x] <= 2000, "CO_group"] = "Good"
    pd_df.loc[pd_df[x] >= 2001, "CO_group"] = "Moderate"
    pd_df.loc[pd_df[x] >= 4001, "CO_group"] = "Unhealthy for Sensitive"
    pd_df.loc[pd_df[x] >= 14001, "CO_group"] = "Unhealthy"
    pd_df.loc[pd_df[x] >= 24001, "CO_group"] = "Very unhealthy"
    pd_df.loc[pd_df[x] >= 36001, "CO_group"] = "Hazardous"
for x in pd_df[["O3"]]:
    pd_df.loc[pd_df[x] <= 100, "O3_group"] = "Good"
    pd_df.loc[pd_df[x] >= 101, "O3_group"] = "Moderate"
    pd_df.loc[pd_df[x] >= 161, "O3_group"] = "Unhealthy for Sensitive"
    pd_df.loc[pd_df[x] >= 216, "O3_group"] = "Unhealthy"
    pd_df.loc[pd_df[x] >= 266, "O3_group"] = "Very unhealthy"
    pd_df.loc[pd_df[x] >= 801, "O3_group"] = "Hazardous"
for x in pd_df[["PM25"]]:
    pd_df.loc[pd_df[x] <= 35, "PM25_group"] = "Good"
    pd_df.loc[pd_df[x] >= 36, "PM25_group"] = "Moderate"
    pd_df.loc[pd_df[x] >= 76, "PM25_group"] = "Unhealthy for Sensitive"
    pd_df.loc[pd_df[x] >= 126, "PM25_group"] = "Unhealthy"
    pd_df.loc[pd_df[x] >= 151, "PM25_group"] = "Very unhealthy"
    pd_df.loc[pd_df[x] >= 251, "PM25_group"] = "Hazardous"
print(pd_df["PM25_group"].unique())
# Out:
# ['Good' 'Moderate' 'Unhealthy for Sensitive' 'Unhealthy' 'Very unhealthy'
#  'Hazardous']

# %%
pd_df
# Out:
#        PM25   PM10   SO2    NO2      CO     O3       station  \
# 0       4.0    4.0   4.0    7.0   300.0   77.0  Aotizhongxin
# 1       8.0    8.0   4.0    7.0   300.0   77.0  Aotizhongxin
# 2       7.0    7.0   5.0   10.0   300.0   73.0  Aotizhongxin
# 3       6.0    6.0  11.0   11.0   300.0   72.0  Aotizhongxin
# 4       3.0    3.0  12.0   12.0   300.0   72.0  Aotizhongxin
# 5       5.0    5.0  18.0   18.0   400.0   66.0  Aotizhongxin
# 6       3.0    3.0  18.0   32.0   500.0   50.0  Aotizhongxin
# 7       3.0    6.0  19.0   41.0   500.0   43.0  Aotizhongxin
# 8       3.0    6.0  16.0   43.0   500.0   45.0  Aotizhongxin
# 9       3.0    8.0  12.0   28.0   400.0   59.0  Aotizhongxin
# 10      3.0    6.0   9.0   12.0   400.0   72.0  Aotizhongxin
# 11      3.0    6.0   9.0   14.0   400.0   71.0  Aotizhongxin
# 12      3.0    6.0   7.0   13.0   300.0   74.0  Aotizhongxin
# 13      3.0    6.0   7.0   12.0   400.0   76.0  Aotizhongxin
# 14      6.0    9.0   7.0   11.0   400.0   77.0  Aotizhongxin
# 15      8.0   15.0   7.0   14.0   400.0   76.0  Aotizhongxin
# 16      9.0   19.0   9.0   13.0   400.0   76.0  Aotizhongxin
# 17     10.0   23.0  11.0   15.0   400.0   74.0  Aotizhongxin
# 18     11.0   20.0   8.0   20.0   500.0   70.0  Aotizhongxin
# 19      8.0   14.0  12.0   30.0   500.0   60.0  Aotizhongxin
# 20     11.0   17.0  13.0   33.0   600.0   55.0  Aotizhongxin
# 21     12.0   18.0  16.0   35.0   500.0   50.0  Aotizhongxin
# 22     15.0   19.0  21.0   57.0   700.0   32.0  Aotizhongxin
# 23     24.0   24.0  26.0   54.0   600.0   36.0  Aotizhongxin
# 35062  2017-2-28 22:00:00  Unhealthy for Sensitive      Good       Good
# 35063  2017-2-28 23:00:00                 Moderate      Good       Good
#
#       CO_group  O3_group PM25_group
# 0         Good      Good       Good
# 1         Good      Good       Good
# 2         Good      Good       Good
# 3         Good      Good       Good
# 4         Good      Good       Good
# 5         Good      Good       Good
# 6         Good      Good       Good
# 7         Good      Good       Good
# 8         Good      Good       Good
# 9         Good      Good       Good
# 10        Good      Good       Good
# 11        Good      Good       Good
# 12        Good      Good       Good
# 13        Good      Good       Good
# 14        Good      Good       Good
# 15        Good      Good       Good
# 16        Good      Good       Good
# 17        Good      Good       Good
# 18        Good      Good       Good
# 19        Good      Good       Good
# 20        Good      Good       Good
# 21        Good      Good       Good
# 22        Good      Good       Good
# 23        Good      Good       Good
# 24        Good      Good       Good
# 25        Good      Good       Good
# 26        Good      Good       Good
# 27        Good      Good       Good
# 28        Good      Good       Good
# 29        Good      Good       Good
# ...        ...       ...        ...
# 35034     Good  Moderate   Moderate
# 35035     Good      Good   Moderate
# 35036     Good      Good   Moderate
# 35037     Good      Good   Moderate
# 35038     Good      Good   Moderate
# 35039     Good      Good   Moderate
# 35040     Good      Good   Moderate
# 35041     Good      Good       Good
# 35042     Good      Good       Good
# 35043     Good      Good       Good
# 35044     Good      Good       Good
# 35045     Good      Good       Good
# 35046     Good      Good       Good
# 35047     Good      Good       Good
# 35048     Good      Good       Good
# 35049     Good      Good       Good
# 35050     Good      Good       Good
# 35051     Good  Moderate       Good
# 35052     Good  Moderate       Good
# 35053     Good  Moderate       Good
# 35054     Good  Moderate       Good
# 35055     Good  Moderate       Good
# 35056     Good  Moderate       Good
# 35057     Good  Moderate       Good
# 35058     Good  Moderate       Good
# 35059     Good      Good       Good
# 35060     Good      Good       Good
# 35061     Good      Good       Good
# 35062     Good      Good       Good
# 35063     Good      Good       Good
#
# [31896 rows x 14 columns]

# %%
import pandas as pd
aotizhongxin = pd.read_csv("PRSA_Data_Aotizhongxin_20130301-20170228.csv")
Changping = pd.read_csv("PRSA_Data_Changping_20130301-20170228.csv")
Dingling = pd.read_csv("PRSA_Data_Dingling_20130301-20170228.csv")
Dongsi = pd.read_csv("PRSA_Data_Dongsi_20130301-20170228.csv")
Guanyuan = pd.read_csv("PRSA_Data_Guanyuan_20130301-20170228.csv")
Gucheng = pd.read_csv("PRSA_Data_Gucheng_20130301-20170228.csv")
Huairou = pd.read_csv("PRSA_Data_Huairou_20130301-20170228.csv")
Nongzhanguan = pd.read_csv("PRSA_Data_Nongzhanguan_20130301-20170228.csv")
Shunyi = pd.read_csv("PRSA_Data_Shunyi_20130301-20170228.csv")
Tiantan = pd.read_csv("PRSA_Data_Tiantan_20130301-20170228.csv")
Wanliu = pd.read_csv("PRSA_Data_Wanliu_20130301-20170228.csv")
Wanshouxigong = pd.read_csv("PRSA_Data_Wanshouxigong_20130301-20170228.csv")
df = pd.DataFrame(aotizhongxin)
df1 = pd.DataFrame(Changping)
df2 = pd.DataFrame(Dingling)
df3 = pd.DataFrame(Dongsi)
df4 = pd.DataFrame(Guanyuan)
df5 = pd.DataFrame(Gucheng)
df6 = pd.DataFrame(Huairou)
df7 = pd.DataFrame(Nongzhanguan)
df8 = pd.DataFrame(Shunyi)
df9 = pd.DataFrame(Tiantan)
df10 = pd.DataFrame(Wanliu)
df11 = pd.DataFrame(Wanshouxigong)
df = df.append(df1,ignore_index=True)
df = df.append(df2,ignore_index=True)
df = df.append(df3,ignore_index=True)
df = df.append(df4,ignore_index=True)
df = df.append(df5,ignore_index=True)
df = df.append(df6,ignore_index=True)
df = df.append(df7,ignore_index=True)
df = df.append(df8,ignore_index=True)
df = df.append(df9,ignore_index=True)
df = df.append(df10,ignore_index=True)
df = df.append(df11,ignore_index=True)
print("Whole dataset: ",df.shape)
new_df = df[["year","month","day","hour","PM2.5","PM10","SO2","NO2","CO","O3","station"]]
new_df = new_df.dropna(axis=0,how='any')
print("After removing missing value: ",new_df.shape)
# Out:
# /home/ubuntu/.local/lib/python3.5/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# Whole dataset:  (420768, 19)
# After removing missing value:  (352084, 11)

# %%
for x in new_df[["PM2.5","PM10","SO2","NO2","CO","O3"]]:
    q75, q25 = np.percentile(new_df.loc[:, x], [75, 25])
    intr_qr = q75 - q25
    max = q75 + (1.5 * intr_qr)
    min = q25 - (1.5 * intr_qr)

    new_df.loc[new_df[x] < min, x] = intr_qr
    new_df.loc[new_df[x] > max, x] = intr_qr
new_df['Time']= new_df['year'].map(str)+'-'+new_df['month'].map(str)+'-'+ new_df['day'].map(str)+' '+ new_df['hour'].map(str)+':00:00'
new_df = new_df[["PM2.5","PM10","SO2","NO2","CO","O3","station","Time"]]
for x in new_df[["NO2"]]:
    new_df.loc[new_df[x] <= 40, "NO2_group"] = "Good"
    new_df.loc[new_df[x] >= 41, "NO2_group"] = "Moderate"
    new_df.loc[new_df[x] >= 81, "NO2_group"] = "Unhealthy for Sensitive"
    new_df.loc[new_df[x] >= 181, "NO2_group"] = "Unhealthy"
    new_df.loc[new_df[x] >= 281, "NO2_group"] = "Very unhealthy"
    new_df.loc[new_df[x] >= 566, "NO2_group"] = "Hazardous"
for x in new_df[["SO2"]]:
    new_df.loc[new_df[x] <= 50, "SO2_group"] = "Good"
    new_df.loc[new_df[x] >= 51, "SO2_group"] = "Moderate"
    new_df.loc[new_df[x] >= 150, "SO2_group"] = "Unhealthy for Sensitive"
    new_df.loc[new_df[x] >= 476, "SO2_group"] = "Unhealthy"
    new_df.loc[new_df[x] >= 801, "SO2_group"] = "Very unhealthy"
    new_df.loc[new_df[x] >= 1601, "SO2_group"] = "Hazardous"
for x in new_df[["PM10"]]:
    new_df.loc[new_df[x] <= 50, "PM10_group"] = "Good"
    new_df.loc[new_df[x] >= 51, "PM10_group"] = "Moderate"
    new_df.loc[new_df[x] >= 151, "PM10_group"] = "Unhealthy for Sensitive"
    new_df.loc[new_df[x] >= 251, "PM10_group"] = "Unhealthy"
    new_df.loc[new_df[x] >= 351, "PM10_group"] = "Very unhealthy"
    new_df.loc[new_df[x] >= 421, "PM10_group"] = "Hazardous"
for x in new_df[["CO"]]:
    new_df.loc[new_df[x] <= 2000, "CO_group"] = "Good"
    new_df.loc[new_df[x] >= 2001, "CO_group"] = "Moderate"
    new_df.loc[new_df[x] >= 4001, "CO_group"] = "Unhealthy for Sensitive"
    new_df.loc[new_df[x] >= 14001, "CO_group"] = "Unhealthy"
    new_df.loc[new_df[x] >= 24001, "CO_group"] = "Very unhealthy"
    new_df.loc[new_df[x] >= 36001, "CO_group"] = "Hazardous"
for x in new_df[["O3"]]:
    new_df.loc[new_df[x] <= 100, "O3_group"] = "Good"
    new_df.loc[new_df[x] >= 101, "O3_group"] = "Moderate"
    new_df.loc[new_df[x] >= 161, "O3_group"] = "Unhealthy for Sensitive"
    new_df.loc[new_df[x] >= 216, "O3_group"] = "Unhealthy"
    new_df.loc[new_df[x] >= 266, "O3_group"] = "Very unhealthy"
    new_df.loc[new_df[x] >= 801, "O3_group"] = "Hazardous"
for x in new_df[["PM2.5"]]:
    new_df.loc[new_df[x] <= 35, "PM2.5_group"] = "Good"
    new_df.loc[new_df[x] >= 36, "PM2.5_group"] = "Moderate"
    new_df.loc[new_df[x] >= 76, "PM2.5_group"] = "Unhealthy for Sensitive"
    new_df.loc[new_df[x] >= 126, "PM2.5_group"] = "Unhealthy"
    new_df.loc[new_df[x] >= 151, "PM2.5_group"] = "Very unhealthy"
    new_df.loc[new_df[x] >= 251, "PM2.5_group"] = "Hazardous"
new_df
# Out:
#         PM2.5   PM10   SO2    NO2      CO    O3        station  \
# 35064     3.0    6.0  13.0    7.0   300.0  85.0      Changping
# 35065     3.0    3.0   6.0    6.0   300.0  85.0      Changping
# 35066     3.0    3.0  22.0   13.0   400.0  74.0      Changping
# 35067     3.0    6.0  12.0    8.0   300.0  81.0      Changping
# 35068     3.0    3.0  14.0    8.0   300.0  81.0      Changping
# 35069     3.0    3.0  10.0   17.0   400.0  71.0      Changping
# 35070     4.0    6.0  12.0   22.0   500.0  65.0      Changping
# 35071     3.0    6.0  25.0   39.0   600.0  48.0      Changping
# 35072     9.0   25.0  13.0   42.0   700.0  46.0      Changping
# 35073    11.0   29.0   5.0   18.0   500.0  73.0      Changping
# 35074     9.0   10.0   3.0   10.0   300.0  83.0      Changping
# 35075     3.0    3.0   4.0    9.0   300.0  81.0      Changping
# 35076     3.0    6.0   4.0    8.0   300.0  90.0      Changping
# 35077     3.0  101.0   5.0    9.0   300.0  89.0      Changping
# 35078     9.0   60.0   5.0    6.0   300.0  94.0      Changping
# 35079     3.0   34.0   6.0    7.0   300.0  94.0      Changping
# 35080     3.0   28.0   5.0    9.0   300.0  92.0      Changping
# 35081     6.0   25.0  19.0   12.0   300.0  88.0      Changping
# 35082     4.0   17.0  40.0   22.0   600.0  77.0      Changping
# 35083     7.0   19.0  37.0   22.0   600.0  75.0      Changping
# 35084     8.0   21.0  23.0   14.0   300.0  80.0      Changping
# 35085     7.0   16.0  34.0   19.0   300.0  74.0      Changping
# 35086     5.0   13.0  25.0   16.0   300.0  76.0      Changping
# 35087     7.0   12.0  43.0   25.0   500.0  65.0      Changping
# 35088    11.0   13.0  23.0   16.0   400.0  69.0      Changping
# 420765  2017-2-28 21:00:00                     Good      Good       Good
# 420766  2017-2-28 22:00:00                     Good      Good       Good
# 420767  2017-2-28 23:00:00                     Good      Good       Good
#
#        CO_group O3_group              PM2.5_group
# 35064      Good     Good                     Good
# 35065      Good     Good                     Good
# 35066      Good     Good                     Good
# 35067      Good     Good                     Good
# 35068      Good     Good                     Good
# 35069      Good     Good                     Good
# 35070      Good     Good                     Good
# 35071      Good     Good                     Good
# 35072      Good     Good                     Good
# 35073      Good     Good                     Good
# 35074      Good     Good                     Good
# 35075      Good     Good                     Good
# 35076      Good     Good                     Good
# 35077      Good     Good                     Good
# 35078      Good     Good                     Good
# 35079      Good     Good                     Good
# 35080      Good     Good                     Good
# 35081      Good     Good                     Good
# 35082      Good     Good                     Good
# 35083      Good     Good                     Good
# 35084      Good     Good                     Good
# 35085      Good     Good                     Good
# 35086      Good     Good                     Good
# 35087      Good     Good                     Good
# 35088      Good     Good                     Good
# 35089      Good     Good                     Good
# 35093      Good     Good                     Good
# 35094      Good     Good                     Good
# 35095      Good     Good                     Good
# 35096      Good     Good                     Good
# ...         ...      ...                      ...
# 420735     Good     Good  Unhealthy for Sensitive
# 420736     Good     Good                 Moderate
# 420737     Good     Good                 Moderate
# 420738     Good     Good                 Moderate
# 420739     Good     Good                 Moderate
# 420740     Good     Good                 Moderate
# 420741     Good     Good                 Moderate
# 420742     Good     Good                 Moderate
# 420743     Good     Good                 Moderate
# 420744     Good     Good                 Moderate
# 420745     Good     Good                     Good
# 420746     Good     Good                     Good
# 420747     Good     Good                     Good
# 420748     Good     Good                     Good
# 420749     Good     Good                     Good
# 420750     Good     Good                     Good
# 420751     Good     Good                     Good
# 420752     Good     Good                     Good
# 420753     Good     Good                     Good
# 420754     Good     Good                     Good
# 420755     Good     Good                     Good
# 420756     Good     Good                     Good
# 420757     Good     Good                     Good
# 420761     Good     Good                     Good
# 420762     Good     Good                     Good
# 420763     Good     Good                     Good
# 420764     Good     Good                     Good
# 420765     Good     Good                     Good
# 420766     Good     Good                     Good
# 420767     Good     Good                     Good
#
# [352084 rows x 14 columns]

# %%
pd_df.sort_values(by=["station","Time"],inplace=True,ascending=[True,True])
print(pd_df[["station","Time"]])
for x in pd_df[["PM25_group","SO2_group","NO2_group","CO_group","O3_group"]]:
    pd_df.loc[pd_df[x] == "Good", x] = "Good"
    pd_df.loc[pd_df[x] == "Moderate", x] = "Good"
    pd_df.loc[pd_df[x] == "Unhealthy" , x] = "Unhealthy"
    pd_df.loc[pd_df[x] == "Unhealthy for Sensitive", x] = "Unhealthy"
    pd_df.loc[pd_df[x] == "Very unhealthy", x] = "Unhealthy"
    pd_df.loc[pd_df[x] == "Hazardous", x] = "Unhealthy"
pd_df
# Out:
#             station                 Time
# 5136   Aotizhongxin    2013-10-1 0:00:00
# 5146   Aotizhongxin   2013-10-1 10:00:00
# 5149   Aotizhongxin   2013-10-1 13:00:00
# 5137   Aotizhongxin    2013-10-1 1:00:00
# 5157   Aotizhongxin   2013-10-1 21:00:00
# 5158   Aotizhongxin   2013-10-1 22:00:00
# 5375   2013-10-10 23:00:00       Good      Good                     Good
# 5354    2013-10-10 2:00:00       Good      Good  Unhealthy for Sensitive
# 5355    2013-10-10 3:00:00       Good      Good  Unhealthy for Sensitive
# 5356    2013-10-10 4:00:00       Good      Good  Unhealthy for Sensitive
# 5357    2013-10-10 5:00:00       Good      Good  Unhealthy for Sensitive
# 5358    2013-10-10 6:00:00       Good      Good  Unhealthy for Sensitive
# 5359    2013-10-10 7:00:00       Good      Good  Unhealthy for Sensitive
# ...                    ...        ...       ...                      ...
# 34562     2017-2-8 2:00:00  Unhealthy      Good                 Moderate
# 34563     2017-2-8 3:00:00  Unhealthy      Good                 Moderate
# 34564     2017-2-8 4:00:00  Unhealthy      Good                 Moderate
# 34565     2017-2-8 5:00:00       Good      Good                 Moderate
# 34566     2017-2-8 6:00:00       Good      Good                 Moderate
# 34567     2017-2-8 7:00:00       Good      Good                     Good
# 34568     2017-2-8 8:00:00       Good      Good                 Moderate
# 34569     2017-2-8 9:00:00       Good      Good                     Good
# 34584     2017-2-9 0:00:00       Good      Good                     Good
# 34594    2017-2-9 10:00:00       Good      Good                     Good
# 34595    2017-2-9 11:00:00       Good      Good                     Good
# 34596    2017-2-9 12:00:00       Good      Good                     Good
# 34597    2017-2-9 13:00:00       Good      Good                     Good
# 34598    2017-2-9 14:00:00       Good      Good                     Good
# 34599    2017-2-9 15:00:00       Good      Good                     Good
# 34600    2017-2-9 16:00:00       Good      Good                     Good
# 34601    2017-2-9 17:00:00       Good      Good                     Good
# 34603    2017-2-9 19:00:00       Good      Good                     Good
# 34585     2017-2-9 1:00:00       Good      Good                     Good
# 34604    2017-2-9 20:00:00       Good      Good                     Good
# 34605    2017-2-9 21:00:00       Good      Good                     Good
# 34606    2017-2-9 22:00:00       Good      Good                     Good
# 34607    2017-2-9 23:00:00       Good      Good                     Good
# 34586     2017-2-9 2:00:00       Good      Good                     Good
# 34588     2017-2-9 4:00:00       Good      Good                     Good
# 34589     2017-2-9 5:00:00       Good      Good                     Good
# 34590     2017-2-9 6:00:00       Good      Good                     Good
# 34591     2017-2-9 7:00:00       Good      Good                     Good
# 34592     2017-2-9 8:00:00       Good      Good                     Good
# 34593     2017-2-9 9:00:00       Good      Good                     Good
#
#       CO_group O3_group PM25_group
# 5136      Good     Good  Unhealthy
# 5146      Good     Good       Good
# 5149      Good     Good       Good
# 5137      Good     Good  Unhealthy
# 5157      Good     Good       Good
# 5158      Good     Good       Good
# 5159      Good     Good       Good
# 5138      Good     Good  Unhealthy
# 5139      Good     Good  Unhealthy
# 5140      Good     Good  Unhealthy
# 5141      Good     Good  Unhealthy
# 5142      Good     Good  Unhealthy
# 5143      Good     Good  Unhealthy
# 5144      Good     Good  Unhealthy
# 5145      Good     Good  Unhealthy
# 5352      Good     Good  Unhealthy
# 5362      Good     Good       Good
# 5363      Good     Good       Good
# 5364      Good     Good       Good
# 5365      Good     Good       Good
# 5353      Good     Good  Unhealthy
# 5373      Good     Good       Good
# 5374      Good     Good       Good
# 5375      Good     Good       Good
# 5354      Good     Good  Unhealthy
# 5355      Good     Good  Unhealthy
# 5356      Good     Good  Unhealthy
# 5357      Good     Good  Unhealthy
# 5358      Good     Good  Unhealthy
# 5359      Good     Good  Unhealthy
# ...        ...      ...        ...
# 34562     Good     Good  Unhealthy
# 34563     Good     Good  Unhealthy
# 34564     Good     Good  Unhealthy
# 34565     Good     Good  Unhealthy
# 34566     Good     Good       Good
# 34567     Good     Good       Good
# 34568     Good     Good       Good
# 34569     Good     Good       Good
# 34584     Good     Good       Good
# 34594     Good     Good       Good
# 34595     Good     Good       Good
# 34596     Good     Good       Good
# 34597     Good     Good       Good
# 34598     Good     Good       Good
# 34599     Good     Good       Good
# 34600     Good     Good       Good
# 34601     Good     Good       Good
# 34603     Good     Good       Good
# 34585     Good     Good       Good
# 34604     Good     Good       Good
# 34605     Good     Good       Good
# 34606     Good     Good       Good
# 34607     Good     Good       Good
# 34586     Good     Good       Good
# 34588     Good     Good       Good
# 34589     Good     Good       Good
# 34590     Good     Good       Good
# 34591     Good     Good       Good
# 34592     Good     Good       Good
# 34593     Good     Good       Good
#
# [31896 rows x 14 columns]

# %%
pd_df["PM25"] = np.log(pd_df["PM25"])
pd_df["PM10"] = np.log(pd_df["PM10"])
pd_df["SO2"] = np.log(pd_df["SO2"])
pd_df["NO2"] = np.log(pd_df["NO2"])
pd_df["CO"] = np.log(pd_df["CO"])
pd_df["O3"] = np.log(pd_df["O3"])

# %%
final_data = pd.read_csv("final_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-b765273aa737> in <module>()
# ----> 1 final_data = pd.read_csv("final_data.csv")
#
# NameError: name 'pd' is not defined

# %%
final_data
# Out:
#            PM2.5       SO2       NO2        CO        O3      PM10  \
# 0       5.389072  3.135494  4.744932  7.649693  0.000000  5.484797
# 1       3.688879  2.079442  3.806662  6.551080  3.258097  1.945910
# 2       3.091042  1.791759  3.433987  5.991465  3.784190  2.484907
# 3       5.480639  3.044522  4.644391  7.696213  0.000000  5.575949
# 4       3.610918  1.945910  4.330733  6.907755  0.000000  4.304065
# 5       3.713572  1.609438  4.290459  6.551080  0.000000  4.043051
# 6       3.688879  1.609438  4.094345  6.214608  1.098612  3.828641
# 7       5.267858  2.944439  4.454347  7.549609  0.000000  5.370638
# 8       5.141664  2.890372  4.382027  7.438384  0.000000  5.241747
# 9       4.990433  2.772589  4.330733  7.313220  0.000000  5.081404
# 10      4.875197  2.708050  4.262680  7.170120  0.000000  4.976734
# 11      4.812184  2.564949  4.262680  7.170120  0.000000  4.867534
# 12      4.574711  2.484907  4.143135  7.090077  0.000000  4.663439
# 13      4.682131  2.397895  4.143135  7.170120  0.000000  4.718499
# 14      4.521789  2.302585  4.127134  6.802395  1.386294  4.718499
# 15      5.252273  2.833213  4.543295  7.438384  1.945910  5.493061
# 16      2.890372  2.833213  2.833213  5.703782  3.526361  4.804021
# 17      2.639057  3.761200  2.564949  5.298317  3.637586  4.521789
# 18      2.833213  3.761200  2.484907  4.605170  3.737670  4.510860
# 19      2.772589  3.761200  2.302585  4.605170  3.806662  4.574711
# 20      5.241747  2.833213  4.406719  7.313220  1.791759  5.283204
# 383910  Wanshouxigong    2017-2-9 16:00:00        Good      Good       Good
# 383911  Wanshouxigong    2017-2-9 17:00:00        Good      Good       Good
# 383912  Wanshouxigong    2017-2-9 18:00:00        Good      Good       Good
# 383913  Wanshouxigong    2017-2-9 19:00:00        Good      Good       Good
# 383914  Wanshouxigong     2017-2-9 1:00:00        Good      Good       Good
# 383915  Wanshouxigong    2017-2-9 20:00:00        Good      Good       Good
# 383916  Wanshouxigong    2017-2-9 21:00:00        Good      Good       Good
# 383917  Wanshouxigong    2017-2-9 22:00:00        Good      Good       Good
# 383918  Wanshouxigong    2017-2-9 23:00:00        Good      Good       Good
# 383919  Wanshouxigong     2017-2-9 2:00:00        Good      Good       Good
# 383920  Wanshouxigong     2017-2-9 4:00:00        Good      Good       Good
# 383921  Wanshouxigong     2017-2-9 5:00:00        Good      Good       Good
# 383922  Wanshouxigong     2017-2-9 6:00:00        Good      Good       Good
# 383923  Wanshouxigong     2017-2-9 7:00:00        Good      Good       Good
# 383924  Wanshouxigong     2017-2-9 8:00:00        Good      Good       Good
# 383925  Wanshouxigong     2017-2-9 9:00:00        Good      Good       Good
#
#        CO_group O3_group
# 0          Good     Good
# 1          Good     Good
# 2          Good     Good
# 3          Good     Good
# 4          Good     Good
# 5          Good     Good
# 6          Good     Good
# 7          Good     Good
# 8          Good     Good
# 9          Good     Good
# 10         Good     Good
# 11         Good     Good
# 12         Good     Good
# 13         Good     Good
# 14         Good     Good
# 15         Good     Good
# 16         Good     Good
# 17         Good     Good
# 18         Good     Good
# 19         Good     Good
# 20         Good     Good
# 21         Good     Good
# 22         Good     Good
# 23         Good     Good
# 24         Good     Good
# 25         Good     Good
# 26         Good     Good
# 27         Good     Good
# 28         Good     Good
# 29         Good     Good
# ...         ...      ...
# 383896     Good     Good
# 383897     Good     Good
# 383898     Good     Good
# 383899     Good     Good
# 383900     Good     Good
# 383901     Good     Good
# 383902     Good     Good
# 383903     Good     Good
# 383904     Good     Good
# 383905     Good     Good
# 383906     Good     Good
# 383907     Good     Good
# 383908     Good     Good
# 383909     Good     Good
# 383910     Good     Good
# 383911     Good     Good
# 383912     Good     Good
# 383913     Good     Good
# 383914     Good     Good
# 383915     Good     Good
# 383916     Good     Good
# 383917     Good     Good
# 383918     Good     Good
# 383919     Good     Good
# 383920     Good     Good
# 383921     Good     Good
# 383922     Good     Good
# 383923     Good     Good
# 383924     Good     Good
# 383925     Good     Good
#
# [383926 rows x 13 columns]

# %%
corr = final_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row0_col0 {
#             background-color:  #b40426;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row0_col1 {
#             background-color:  #e8d6cc;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row0_col2 {
#             background-color:  #f39577;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row0_col3 {
#             background-color:  #e7745b;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row0_col4 {
#             background-color:  #6b8df0;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row0_col5 {
#             background-color:  #d95847;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row1_col0 {
#             background-color:  #efcfbf;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row1_col1 {
#             background-color:  #b40426;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row1_col2 {
#             background-color:  #f7ba9f;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row1_col3 {
#             background-color:  #f5c0a7;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row1_col4 {
#             background-color:  #84a7fc;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row1_col5 {
#             background-color:  #ebd3c6;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row2_col0 {
#             background-color:  #f7a889;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row2_col1 {
#             background-color:  #ebd3c6;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row2_col2 {
#             background-color:  #b40426;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row2_col3 {
#             background-color:  #f39475;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row2_col4 {
#             background-color:  #3b4cc0;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row2_col5 {
#             background-color:  #f7b396;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row3_col0 {
#             background-color:  #ea7b60;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row3_col1 {
#             background-color:  #edd1c2;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row3_col2 {
#             background-color:  #f08b6e;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row3_col3 {
#             background-color:  #b40426;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row3_col4 {
#             background-color:  #516ddb;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row3_col5 {
#             background-color:  #f6a283;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row4_col0 {
#             background-color:  #3b4cc0;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row4_col1 {
#             background-color:  #3b4cc0;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row4_col2 {
#             background-color:  #3b4cc0;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row4_col3 {
#             background-color:  #3b4cc0;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row4_col4 {
#             background-color:  #b40426;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row4_col5 {
#             background-color:  #3b4cc0;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row5_col0 {
#             background-color:  #d85646;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row5_col1 {
#             background-color:  #e5d8d1;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row5_col2 {
#             background-color:  #f59f80;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row5_col3 {
#             background-color:  #f39778;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row5_col4 {
#             background-color:  #7396f5;
#         }    #T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row5_col5 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >PM2.5</th>
#         <th class="col_heading level0 col1" >SO2</th>
#         <th class="col_heading level0 col2" >NO2</th>
#         <th class="col_heading level0 col3" >CO</th>
#         <th class="col_heading level0 col4" >O3</th>
#         <th class="col_heading level0 col5" >PM10</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5level0_row0" class="row_heading level0 row0" >PM2.5</th>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row0_col0" class="data row0 col0" >1</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row0_col1" class="data row0 col1" >0.451742</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row0_col2" class="data row0 col2" >0.625564</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row0_col3" class="data row0 col3" >0.764397</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row0_col4" class="data row0 col4" >-0.310515</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row0_col5" class="data row0 col5" >0.857566</td>
#     </tr>    <tr>
#         <th id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5level0_row1" class="row_heading level0 row1" >SO2</th>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row1_col0" class="data row1 col0" >0.451742</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row1_col1" class="data row1 col1" >1</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row1_col2" class="data row1 col2" >0.471162</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row1_col3" class="data row1 col3" >0.4848</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row1_col4" class="data row1 col4" >-0.202522</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row1_col5" class="data row1 col5" >0.43778</td>
#     </tr>    <tr>
#         <th id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5level0_row2" class="row_heading level0 row2" >NO2</th>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row2_col0" class="data row2 col0" >0.625564</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row2_col1" class="data row2 col1" >0.471162</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row2_col2" class="data row2 col2" >1</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row2_col3" class="data row2 col3" >0.66373</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row2_col4" class="data row2 col4" >-0.548217</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row2_col5" class="data row2 col5" >0.594379</td>
#     </tr>    <tr>
#         <th id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5level0_row3" class="row_heading level0 row3" >CO</th>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row3_col0" class="data row3 col0" >0.764397</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row3_col1" class="data row3 col1" >0.4848</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row3_col2" class="data row3 col2" >0.66373</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row3_col3" class="data row3 col3" >1</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row3_col4" class="data row3 col4" >-0.429445</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row3_col5" class="data row3 col5" >0.652399</td>
#     </tr>    <tr>
#         <th id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5level0_row4" class="row_heading level0 row4" >O3</th>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row4_col0" class="data row4 col0" >-0.310515</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row4_col1" class="data row4 col1" >-0.202522</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row4_col2" class="data row4 col2" >-0.548217</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row4_col3" class="data row4 col3" >-0.429445</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row4_col4" class="data row4 col4" >1</td>
#         <td id="T_06ec9c3e_c86d_11eb_89f4_12a75e0b66a5row4_col5" class="data row4 col5" >-0.274529</td>
#     </tr>    <tr>

# %%
print(final_data["PM2.5_group"].unique())
# Out:
# ['Unhealthy' 'Good']

# %%
import pandas as pd
import numpy as np
final_data["PM2.5"] = (final_data["PM2.5"]
final_data["PM10"] = (final_data["PM10"])
final_data["SO2"] = (final_data["SO2"])
final_data["NO2"] = (final_data["NO2"])
final_data["CO"] = (final_data["CO"])
final_data["O3"] = (final_data["O3"])
# Out:
#   File "<ipython-input-35-89759fb9bf97>", line 4
#     final_data["PM10"] = (final_data["PM10"])
#              ^
# SyntaxError: invalid syntax

# %%
plt.hist(final_data["PM2.5"])
plt.title("PM2.5")
plt.show()
plt.hist(final_data["PM10"])
plt.title("PM10")
plt.show()
plt.hist(final_data["NO2"])
plt.title("NO2")
plt.show()
plt.hist(final_data["CO"])
plt.title("CO")
plt.show()
plt.hist(final_data["O3"])
plt.title("O3")
plt.show()
plt.hist(final_data["SO2"])
plt.title("SO2")
plt.show()

# %%
data = spark.read.csv('./final_data.csv',header=True, inferSchema =True)

# %%
data.printSchema()
# Out:
# root
#  |-- PM25: double (nullable = true)
#  |-- SO2: double (nullable = true)
#  |-- NO2: double (nullable = true)
#  |-- CO: double (nullable = true)
#  |-- O3: double (nullable = true)
#  |-- PM10: double (nullable = true)
#  |-- station: string (nullable = true)
#  |-- Time: string (nullable = true)
#  |-- PM25_group: string (nullable = true)
#  |-- SO2_group: string (nullable = true)
#  |-- NO2_group: string (nullable = true)
#  |-- CO_group: string (nullable = true)
#  |-- O3_group: string (nullable = true)

# %%
data.head()
# Out:
# Row(PM25=5.38907173, SO2=3.135494216, NO2=4.744932128, CO=7.649692624, O3=0.0, PM10=5.484796933, station='Aotizhongxin', Time='1/10/13 00:00', PM25_group='Unhealthy', SO2_group='Good', NO2_group='Unhealthy', CO_group='Good', O3_group='Good')

# %%
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler

# %%
data.columns
# Out:
# ['PM25',
#  'SO2',
#  'NO2',
#  'CO',
#  'O3',
#  'PM10',
#  'station',
#  'Time',
#  'PM25_group',
#  'SO2_group',
#  'NO2_group',
#  'CO_group',
#  'O3_group']

# %%
assembler = VectorAssembler(
  inputCols=['SO2',
             'NO2',
             'CO',
             'O3',
             'PM10'],
              outputCol="features")

# %%
output = assembler.transform(data)

# %%
from pyspark.ml.feature import StringIndexer

# %%
indexer = StringIndexer(inputCol="PM25_group", outputCol="PrivateIndex")
output_fixed = indexer.fit(output).transform(output)

# %%
final_data = output_fixed.select("features",'PrivateIndex')

# %%
train_data,test_data = final_data.randomSplit([0.7,0.3])

# %%
from pyspark.ml.classification import DecisionTreeClassifier,GBTClassifier,RandomForestClassifier
from pyspark.ml import Pipeline

# %%
dtc = DecisionTreeClassifier(labelCol='PrivateIndex',featuresCol='features')
rfc = RandomForestClassifier(labelCol='PrivateIndex',featuresCol='features')
gbt = GBTClassifier(labelCol='PrivateIndex',featuresCol='features')

# %%
import time
start_time = time.time()
dtc_model = dtc.fit(train_data)
print("dtc--- %s seconds ---" % (time.time() - start_time))
start_time = time.time()
rfc_model = rfc.fit(train_data)
print("dtc--- %s seconds ---" % (time.time() - start_time))
start_time = time.time()
gbt_model = gbt.fit(train_data)
print("dtc--- %s seconds ---" % (time.time() - start_time))
# Out:
# dtc--- 17.65151047706604 seconds ---
# dtc--- 21.061161279678345 seconds ---
# dtc--- 31.418638467788696 seconds ---

# %%
dtc_predictions = dtc_model.transform(test_data)
rfc_predictions = rfc_model.transform(test_data)
gbt_predictions = gbt_model.transform(test_data)

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator

# Note that the label column isn't named label, it's named PrivateIndex in this case.
my_binary_eval = BinaryClassificationEvaluator(labelCol = 'PrivateIndex')

# %%
print("DTC")
print(my_binary_eval.evaluate(dtc_predictions))

# RFC improves accuracy but also model complexity. RFC outperforms DTC in nearly every situation.
print("RFC")
print(my_binary_eval.evaluate(rfc_predictions))

# We can't repeat these exact steps for GBT. If you print the schema of all three, you may be able to notice why.
# Instead, let's redefine the object:
my_binary_gbt_eval = BinaryClassificationEvaluator(labelCol='PrivateIndex', rawPredictionCol='prediction')
print("GBT")
print(my_binary_gbt_eval.evaluate(gbt_predictions))
# Out:
# DTC
# 0.9497002049535608
# RFC
# 0.9707176085130603
# GBT
# 0.9124194829123824

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# %%
acc_evaluator = MulticlassClassificationEvaluator(labelCol="PrivateIndex", predictionCol="prediction", metricName="accuracy")

# %%
import time
start_time = time.time()
dtc_acc = acc_evaluator.evaluate(dtc_predictions)
print("dtc--- %s seconds ---" % (time.time() - start_time))
start_time = time.time()
rfc_acc = acc_evaluator.evaluate(rfc_predictions)
print("rfc--- %s seconds ---" % (time.time() - start_time))
start_time = time.time()
gbt_acc = acc_evaluator.evaluate(gbt_predictions)
print("gbt--- %s seconds ---" % (time.time() - start_time))
# Out:
# dtc--- 5.830805778503418 seconds ---
# rfc--- 5.035691976547241 seconds ---
# gbt--- 4.98955512046814 seconds ---

# %%
print("Here are the results!")
print('-'*40)
print('A single decision tree has an accuracy of: {0:2.2f}%'.format(dtc_acc*100))
print('-'*40)
print('A random forest ensemble has an accuracy of: {0:2.2f}%'.format(rfc_acc*100))
print('-'*40)
print('An ensemble using GBT has an accuracy of: {0:2.2f}%'.format(gbt_acc*100))
# Out:
# Here are the results!
# ----------------------------------------
# A single decision tree has an accuracy of: 91.41%
# ----------------------------------------
# A random forest ensemble has an accuracy of: 91.28%
# ----------------------------------------
# An ensemble using GBT has an accuracy of: 91.42%

# %%
dtc = DecisionTreeClassifier(labelCol='PrivateIndex',featuresCol='features',maxDepth=10,impurity = 'Entropy')
start_time = time.time()
dtc_model = dtc.fit(train_data)
print("dtc--- %s seconds ---" % (time.time() - start_time))
dtc_predictions = dtc_model.transform(test_data)
print("DTC")
print(my_binary_eval.evaluate(dtc_predictions))
start_time = time.time()
dtc_acc = acc_evaluator.evaluate(dtc_predictions)
print("dtc--- %s seconds ---" % (time.time() - start_time))
print("Here are the results! with maxDpeth=10, impurity='Entropy'")
print('-'*40)
print('A single decision tree has an accuracy of: {0:2.2f}%'.format(dtc_acc*100))
# Out:
# dtc--- 10.35590386390686 seconds ---
# DTC
# 0.9497002049535608
# dtc--- 4.49140477180481 seconds ---
# Here are the results! with maxDpeth=10, impurity='Entropy'
# ----------------------------------------
# A single decision tree has an accuracy of: 91.41%

# %%
dtc = DecisionTreeClassifier(labelCol='PrivateIndex',featuresCol='features',maxDepth=20,impurity = 'Entropy')
start_time = time.time()
dtc_model = dtc.fit(train_data)
print("dtc--- %s seconds ---" % (time.time() - start_time))
dtc_predictions = dtc_model.transform(test_data)
print("DTC")
print(my_binary_eval.evaluate(dtc_predictions))
start_time = time.time()
dtc_acc = acc_evaluator.evaluate(dtc_predictions)
print("dtc--- %s seconds ---" % (time.time() - start_time))
print("Here are the results! with maxDpeth=20, impurity='Entropy'")
print('-'*40)
print('A single decision tree has an accuracy of: {0:2.2f}%'.format(dtc_acc*100))
# Out:
# dtc--- 16.907479524612427 seconds ---
# DTC
# 0.9212056046293526
# dtc--- 5.057047128677368 seconds ---
# Here are the results! with maxDpeth=20, impurity='Entropy'
# ----------------------------------------
# A single decision tree has an accuracy of: 89.20%

# %%
dtc = DecisionTreeClassifier(labelCol='PrivateIndex',featuresCol='features',maxDepth=10,impurity = 'Gini')
start_time = time.time()
dtc_model = dtc.fit(train_data)
print("dtc--- %s seconds ---" % (time.time() - start_time))
dtc_predictions = dtc_model.transform(test_data)
print("DTC")
print(my_binary_eval.evaluate(dtc_predictions))
start_time = time.time()
dtc_acc = acc_evaluator.evaluate(dtc_predictions)
print("dtc--- %s seconds ---" % (time.time() - start_time))
print("Here are the results! with maxDpeth=10, impurity='Gini'")
print('-'*40)
print('A single decision tree has an accuracy of: {0:2.2f}%'.format(dtc_acc*100))
# Out:
# dtc--- 10.22236156463623 seconds ---
# DTC
# 0.9349229028638565
# dtc--- 4.496749401092529 seconds ---
# Here are the results! with maxDpeth=10, impurity='Gini'
# ----------------------------------------
# A single decision tree has an accuracy of: 91.40%

# %%
dtc = DecisionTreeClassifier(labelCol='PrivateIndex',featuresCol='features',maxDepth=20,impurity = 'Gini')
start_time = time.time()
dtc_model = dtc.fit(train_data)
print("dtc--- %s seconds ---" % (time.time() - start_time))
dtc_predictions = dtc_model.transform(test_data)
print("DTC")
print(my_binary_eval.evaluate(dtc_predictions))
start_time = time.time()
dtc_acc = acc_evaluator.evaluate(dtc_predictions)
print("dtc--- %s seconds ---" % (time.time() - start_time))
print("Here are the results! with maxDpeth=20, impurity='Gini'")
print('-'*40)
print('A single decision tree has an accuracy of: {0:2.2f}%'.format(dtc_acc*100))
# Out:
# dtc--- 16.96869730949402 seconds ---
# DTC
# 0.9187082798485089
# dtc--- 5.041982412338257 seconds ---
# Here are the results! with maxDpeth=20, impurity='Gini'
# ----------------------------------------
# A single decision tree has an accuracy of: 88.90%

# %%
#important: need to cast to float type, and order by prediction, else it won't work
preds_and_labels = dtc_predictions.select(['Prediction','PrivateIndex']).withColumn('label', F.col('PrivateIndex').cast(FloatType())).orderBy('prediction')

#select only prediction and label columns
preds_and_labels = preds_and_labels.select(['prediction','PrivateIndex'])

metrics = MulticlassMetrics(preds_and_labels.rdd.map(tuple))

print(metrics.confusionMatrix().toArray())
# Out:
# [[64006.  6366.]
#  [ 6445. 38649.]]

# %%
data.groupBy('PM25_group').count().show()
# Out:
# +----------+------+
# |PM25_group| count|
# +----------+------+
# | Unhealthy|149539|
# |      Good|234387|
# +----------+------+

# %%
# Out:
# DataFrame[PM25: double, SO2: double, NO2: double, CO: double, O3: double, PM10: double, station: string, Time: string, PM25_group: string, SO2_group: string, NO2_group: string, CO_group: string, O3_group: string]
